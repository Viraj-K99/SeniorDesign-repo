# %%
import os
#Change the current working directory to the specific path
os.chdir('C:/Users/user/Pictures/BIEN175B')
#Get the current working directory and print it
current_dir=os.getcwd()
print("Current working directory:", current_dir)
# Out:
# Current working directory: C:\Users\user\Pictures\BIEN175B

# %%
import cv2 #import Computer Vision library

# Load the images
img0 = cv2.imread('blue_img0.png')
img1 = cv2.imread('blue_img1.png')
img2 = cv2.imread('blue_img2.png')
img3 = cv2.imread('blue_img3.png')

import numpy as np #import numerical python library for calculation

#Calculate the Average Pixel Values for color channels in img0,img1,img2,img3
mean0=cv2.mean(img0)
mean0=[round(val,2) for val in mean0[:3]]
                  
mean1=cv2.mean(img1)
mean1=[round(val,2) for val in mean1[:3]]

mean2=cv2.mean(img2)
mean2=[round(val,2) for val in mean2[:3]]

mean3=cv2.mean(img3)
mean3=[round(val,2) for val in mean3[:3]]

#Print the average vlaues for each image
print("Below we print the average pixel values of R, G, B component in image-1")
print(mean0[:3])

print("Below we print the average pixel values of R, G, B component in image-2")
print(mean1[:3])

print("Below we print the average pixel values of R, G, B component in image-3")
print(mean2[:3])

print("Below we print the average pixel values of R, G, B component in image-4")
print(mean3[:3])
# Out:
# Read
# Below we print the average pixel values of R, G, B component in image-1
# [207.01, 201.64, 177.72]
# Below we print the average pixel values of R, G, B component in image-2
# [204.42, 201.83, 184.44]
# Below we print the average pixel values of R, G, B component in image-3
# [194.21, 194.35, 178.62]
# Below we print the average pixel values of R, G, B component in image-4
# [169.87, 165.69, 150.87]

# %%
import numpy as np #imported numerical python library for calculation
import matplotlib.pyplot as plt #imported for interactive plots generation

# Define the data
labels = ['Simply Spiked(5%)', 'Smirnoff(4.5%)', 'Cayman Jack(5.8%)', 'Cayman Jack(5.8%)\n+Black Dye']
#Subtract the obtained RGB values by 255. This will give higher RGB vlaues for darker colors 
red_means = [255-207.01,255-204.42, 255-194.21, 255-169.87]
green_means = [255-201.64,255-201.83, 255-194.35, 255-165.69]
blue_means = [255-177.72,255-184.44, 255-178.62, 255-150.87]

# Set the positions and width of the bars
pos = np.arange(len(labels))
width = 0.25
offset=0.12

# Create the figure and axis objects
fig, ax = plt.subplots(figsize=(10, 6))

# Create the bar plots
rects1 = ax.bar(pos, red_means, width, color='r', alpha=0.5)
rects2 = ax.bar(pos + width, green_means, width, color='g', alpha=0.5)
rects3 = ax.bar(pos + 2 * width, blue_means, width, color='b', alpha=0.5)

# Set the axis labels and title
ax.set_xlabel('Test Strip Samples of Hard Seltzers with \u22482% Diphenhydramine HCl (Benadryl)')
ax.set_ylabel('RGB Color Intensity (Pixels)')
ax.set_title('RGB Color Intensity Analysis of Test Strip Samples')

# Set the axis ticks and tick labels
ax.set_xticks(pos + width * 1.5-offset)
ax.set_xticklabels(labels,  ha='center')
ax.set_yticks(np.arange(0, 256, 25))

# Add the legend
ax.legend((rects1[0], rects2[0], rects3[0]), ('Red', 'Green', 'Blue'))

# Display the plot
plt.show()

# %%
import cv2 

# Load the two images
#img0 = cv2.imread('blue_img0.png')
#below are the images for test strip images 
img1 = cv2.imread('Test_Strip_Pic1.png')
img2 = cv2.imread('Test_Strip_Pic2.png')
img3 = cv2.imread('Test_Strip_Pic3.png')

print("Read")
#print(img1)
import numpy as np

import matplotlib.pyplot as plt
                  
mean1=cv2.mean(img1)
mean1=[round(val,2) for val in mean1[:3]]

mean2=cv2.mean(img2)
mean2=[round(val,2) for val in mean2[:3]]

mean3=cv2.mean(img3)
mean3=[round(val,2) for val in mean3[:3]]

print("Below we print the average pixel values of R, G, B component in test strip image-1")
print(mean1[:3])

print("Below we print the average pixel values of R, G, B component in test strip  image-2")
print(mean2[:3])

print("Below we print the average pixel values of R, G, B component in test strip image-3")
print(mean3[:3])
# Out:
# Read
# Below we print the average pixel values of R, G, B component in test strip image-1
# [0.0, 0.0, 0.0]
# Below we print the average pixel values of R, G, B component in test strip  image-2
# [0.0, 0.0, 0.0]
# Below we print the average pixel values of R, G, B component in test strip image-3
# [0.0, 0.0, 0.0]

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the data
labels = ['Sample 1', 'Sample 2', 'Sample 3']
red_means = [255-164.59,255-181.4, 255-171.67]
green_means = [255-174.12,255-192.14, 255-176.61]
blue_means = [255-188.31,255-214.79, 255-208.08]

# Set the positions and width of the bars
pos = np.arange(len(labels))
width = 0.25
offset=0.12

# Create the figure and axis objects
fig, ax = plt.subplots(figsize=(8, 6))

# Create the bar plots
rects1 = ax.bar(pos, red_means, width, color='r', alpha=0.5)
rects2 = ax.bar(pos + width, green_means, width, color='g', alpha=0.5)
rects3 = ax.bar(pos + 2 * width, blue_means, width, color='b', alpha=0.5)

# Set the axis labels and title
ax.set_xlabel('Saturated Test Strip Samples')
ax.set_ylabel('Color Intensity(RGB Values)')
ax.set_title('Comparison of RGB Values for Test Strip with Reagent')

# Set the axis ticks and tick labels
ax.set_xticks(pos + width * 1.5-offset)
ax.set_xticklabels(labels, ha='center')
ax.set_yticks(np.arange(0, 256, 25))

# Add the legend
ax.legend((rects1[0], rects2[0], rects3[0]), ('Red', 'Green', 'Blue'))

# Display the plot
plt.show()

# %%
import cv2 

# Load the two images
#img0 = cv2.imread('blue_img0.png')
img1 = cv2.imread('After30mins_Pic1.png')
img2 = cv2.imread('After30mins_Pic2.png')
#img3 = cv2.imread('Test_Strip_Pic3.png')

print("Read")
#print(img1)
import numpy as np

import matplotlib.pyplot as plt
                  
mean1=cv2.mean(img1)
mean1=[round(val,2) for val in mean1[:3]]

mean2=cv2.mean(img2)
mean2=[round(val,2) for val in mean2[:3]]

#mean3=cv2.mean(img3)
#mean3=[round(val,2) for val in mean3[:3]]


#print("Below we print the average pixel values of R, G, B component in image-1")
#print(mean0[:3])

print("Below we print the average pixel values of R, G, B component in image-1")
print(mean1[:3])

print("Below we print the average pixel values of R, G, B component in image-2")
print(mean2[:3])

#print("Below we print the average pixel values of R, G, B component in image-4")
#print(mean3[:3])
# Out:
# Read
# Below we print the average pixel values of R, G, B component in image-1
# [149.37, 147.99, 120.6]
# Below we print the average pixel values of R, G, B component in image-2
# [134.31, 132.38, 104.91]

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the data
labels = ['Sample 1', 'Sample 2']
red_means = [255-149.37,255-134.31]
green_means = [255-147.99,255-132.38]
blue_means = [255-120,255-104.91]

#red_means = [149.37,134.31]
#green_means = [147.99,132.38]
#blue_means = [120,104.91]


# Set the positions and width of the bars
pos = np.arange(len(labels))
width = 0.25
offset=0.12


# Create the figure and axis objects
fig, ax = plt.subplots(figsize=(8, 6))

# Create the bar plots
rects1 = ax.bar(pos, red_means, width, color='r', alpha=0.5)
rects2 = ax.bar(pos + width, green_means, width, color='g', alpha=0.5)
rects3 = ax.bar(pos + 2 * width, blue_means, width, color='b', alpha=0.5)

# Set the axis labels and title
ax.set_xlabel('Test Strip Samples')
ax.set_ylabel('RGB Color Intensity (Pixels)')
ax.set_title('RGB values for Loss of Water Molecules')

# Set the axis ticks and tick labels
ax.set_xticks(pos + width * 1.5-offset)
ax.set_xticklabels(labels, ha='center')
ax.set_yticks(np.arange(0, 256, 25))

# Add the legend
ax.legend((rects1[0], rects2[0], rects3[0]), ('Red', 'Green', 'Blue'))

# Display the plot
plt.show()

# %%
import cv2 

# Load the two images
#img0 = cv2.imread('blue_img0.png')
img1 = cv2.imread('After19days_Pic1.png')
img2 = cv2.imread('After19days_Pic2.png')
img3 = cv2.imread('After19days_Pic3.png')

print("Read")
#print(img1)
import numpy as np

import matplotlib.pyplot as plt

#mean0=cv2.mean(img0)
#mean0=[round(val,2) for val in mean0[:3]]
                  
mean1=cv2.mean(img1)
mean1=[round(val,2) for val in mean1[:3]]

mean2=cv2.mean(img2)
mean2=[round(val,2) for val in mean2[:3]]

mean3=cv2.mean(img3)
mean3=[round(val,2) for val in mean3[:3]]
#mean3= [x - y for x, y in zip(area256, mean3)]


#print("Below we print the average pixel values of R, G, B component in image-1")
#print(mean0[:3])

print("Below we print the average pixel values of R, G, B component in image-2")
print(mean1[:3])

print("Below we print the average pixel values of R, G, B component in image-3")
print(mean2[:3])

print("Below we print the average pixel values of R, G, B component in image-4")
print(mean3[:3])
# Out:
# Read
# Below we print the average pixel values of R, G, B component in image-2
# [181.47, 171.83, 155.92]
# Below we print the average pixel values of R, G, B component in image-3
# [187.68, 177.91, 164.95]
# Below we print the average pixel values of R, G, B component in image-4
# [171.46, 163.25, 149.09]

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the data
labels = ['Sample 1', 'Sample 2', 'Sample 3']
red_means = [255-181.47,255-171.83, 255-155.92]
green_means = [255-187.68,255-177.91, 255-164.95]
blue_means = [255-171.46,255-163.25, 255-149.09]

# Set the positions and width of the bars
pos = np.arange(len(labels))
width = 0.25
offset=0.12


# Create the figure and axis objects
fig, ax = plt.subplots(figsize=(8, 6))

# Create the bar plots
rects1 = ax.bar(pos, red_means, width, color='r', alpha=0.5)
rects2 = ax.bar(pos + width, green_means, width, color='g', alpha=0.5)
rects3 = ax.bar(pos + 2 * width, blue_means, width, color='b', alpha=0.5)

# Set the axis labels and title
ax.set_xlabel('Test Strip Samples')
ax.set_ylabel('RGB Color Intensity (Pixels)')
ax.set_title('Test Strips After 19 days')

# Set the axis ticks and tick labels
ax.set_xticks(pos + width * 1.5-offset)
ax.set_xticklabels(labels, ha='center')
ax.set_yticks(np.arange(0, 256, 25))

# Add the legend
ax.legend((rects1[0], rects2[0], rects3[0]), ('Red', 'Green', 'Blue'))

# Display the plot
plt.show()

# %%
import cv2 

# Load the two images
#img0 = cv2.imread('blue_img0.png')
img1 = cv2.imread('I2.png')
img2 = cv2.imread('Ben&Kombu_TS1.png')
#img3 = cv2.imread('Test_Strip_Pic3.png')

print("Read")
#print(img1)
import numpy as np

import matplotlib.pyplot as plt

#mean0=cv2.mean(img0)
#mean0=[round(val,2) for val in mean0[:3]]
                  
mean1=cv2.mean(img1)
mean1=[round(val,2) for val in mean1[:3]]

mean2=cv2.mean(img2)
mean2=[round(val,2) for val in mean2[:3]]

#mean3=cv2.mean(img3)
#mean3=[round(val,2) for val in mean3[:3]]


#print("Below we print the average pixel values of R, G, B component in image-1")
#print(mean0[:3])

print("Below we print the average pixel values of R, G, B component in image-1")
print(mean1[:3])

print("Below we print the average pixel values of R, G, B component in image-2")
print(mean2[:3])

#print("Below we print the average pixel values of R, G, B component in image-4")
#print(mean3[:3])
# Out:
# Read
# Below we print the average pixel values of R, G, B component in image-1
# [126.43, 129.0, 135.02]
# Below we print the average pixel values of R, G, B component in image-2
# [127.57, 115.77, 86.97]

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the data
labels = [' Non-Tested Region Of Test Strip', ' Tested Region of Test Strip ']
#red_means = [255-137.54,255-127.57]
#green_means = [255-141.49,255-115.77]
#blue_means = [255-139.7,255-86.97]

#red_means = [136.66,126.43]
#green_means = [135.92,129.0]
#blue_means = [127.53,135.02]
#

#Water
#red_means = [255-142.3,255-127.32]
#green_means = [255-127.56,255-136.95]
#blue_means = [255-99.0,255-173.65]

#red_means = [142.3,126.32]
#green_means = [127.56,136.95]
#blue_means = [99.0,173.65]

# Set the positions and width of the bars
pos = np.arange(len(labels))
width = 0.25

# Create the figure and axis objects
fig, ax = plt.subplots(figsize=(8, 6))

# Create the bar plots
rects1 = ax.bar(pos, red_means, width, color='r', alpha=0.5)
rects2 = ax.bar(pos + width, green_means, width, color='g', alpha=0.5)
rects3 = ax.bar(pos + 2 * width, blue_means, width, color='b', alpha=0.5)

# Set the axis labels and title
ax.set_xlabel('Strip tested with Water')
ax.set_ylabel('RGB Color Intensity (Pixels)')
ax.set_title('RGB Comparison of Negative Control (in Water) ')
#ax.set_title('RGB Color Comparison of Benadryl in Konbucha ')

offset = 0.12
# Set the axis ticks and tick labels
ax.set_xticks(pos + width * 1.5-offset)
ax.set_xticklabels(labels, ha = 'center')
ax.set_yticks(np.arange(0, 256, 25))

# Add the legend
ax.legend((rects1[0], rects2[0], rects3[0]), ('Red', 'Green', 'Blue'))

# Display the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the data
labels = [' Non-Tested Region Of Test Strip', ' Tested Region of Test Strip ']
red_means = [255-126.43,255-127.57]
green_means = [255-129.0,255-115.7]
blue_means = [255-135.02,255-86.97]

#red_means = [136.66,126.43]
#green_means = [135.92,129.0]
#blue_means = [127.53,135.02]
#
'''
Below we print the average pixel values of R, G, B component in image-1
[126.43, 129.0, 135.02]
Below we print the average pixel values of R, G, B component in image-2
[127.57, 115.77, 86.97]
red_means = [142.3,126.32]
green_means = [127.56,136.95]
blue_means = [99.0,173.65]
'''

# Set the positions and width of the bars
pos = np.arange(len(labels))
width = 0.25

# Create the figure and axis objects
fig, ax = plt.subplots(figsize=(8, 6))

# Create the bar plots
rects1 = ax.bar(pos, red_means, width, color='r', alpha=0.5)
rects2 = ax.bar(pos + width, green_means, width, color='g', alpha=0.5)
rects3 = ax.bar(pos + 2 * width, blue_means, width, color='b', alpha=0.5)

# Set the axis labels and title
ax.set_xlabel('Test Strip Tested in Benadryl+Kombucha')
ax.set_ylabel('RGB Color Intensity (Pixels)')
ax.set_title('RGB Color Comparison of Benadryl in Kombucha ')

offset = 0.12
# Set the axis ticks and tick labels
ax.set_xticks(pos + width * 1.5-offset)
ax.set_xticklabels(labels, ha = 'center')
ax.set_yticks(np.arange(0, 256, 25))

# Add the legend
ax.legend((rects1[0], rects2[0], rects3[0]), ('Red', 'Green', 'Blue'))

# Display the plot
plt.show()

# %%
import cv2 

# Load the two images
#img0 = cv2.imread('blue_img0.png')
#img1 = cv2.imread('Test_Strip_Pic1.png')
#img2 = cv2.imread('Test_Strip_Pic2.png')
img3 = cv2.imread('Test_Strip_Pic3.png')
img4 = cv2.imread('After_Loss_of_Water2.png')

print("Read")
#print(img1)
import numpy as np

import matplotlib.pyplot as plt

#mean0=cv2.mean(img0)
#mean0=[round(val,2) for val in mean0[:3]]
                  
#mean1=cv2.mean(img1)
#mean1=[round(val,2) for val in mean1[:3]]


#mean2=cv2.mean(img2)
#mean2=[round(val,2) for val in mean2[:3]]


mean3=cv2.mean(img3)
mean3=[round(val,2) for val in mean3[:3]]
#mean3= [x - y for x, y in zip(area256, mean3)]

mean4=cv2.mean(img4)
mean4=[round(val,2) for val in mean4[:3]]


#print("Below we print the average pixel values of R, G, B component in image-1")
#print(mean0[:3])

#print("Below we print the average pixel values of R, G, B component in image-2")
#print(mean1[:3])

print("Below we print the average pixel values of R, G, B component in image-3")
print(mean3[:3])

print("Below we print the average pixel values of R, G, B component in image-4")
print(mean4[:3])
# Out:
# Read
# Below we print the average pixel values of R, G, B component in image-3
# [171.67, 176.61, 208.08]
# Below we print the average pixel values of R, G, B component in image-4
# [133.18, 129.92, 100.62]

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the data
"""
labels = ['Sample 1', 'Sample 2', 'Sample 3']
red_means = [255-164.59,255-181.4, 255-171.67]
green_means = [255-174.12,255-192.14, 255-176.61]
blue_means = [255-188.31,255-214.79, 255-208.08]
"""


labels = ['Test Strip with Reagent', 'Test Strip with Reagent \n and Loss of Water Molecule']
red_means = [255-171.67,255-133.18]
green_means = [255-176.61,255-129.92]
blue_means = [255-208.08,255-100.62]

# Set the positions and width of the bars
pos = np.arange(len(labels))
width = 0.25
offset=0.12


# Create the figure and axis objects
fig, ax = plt.subplots(figsize=(8, 6))

# Create the bar plots
rects1 = ax.bar(pos, red_means, width, color='r', alpha=0.5)
rects2 = ax.bar(pos + width, green_means, width, color='g', alpha=0.5)
rects3 = ax.bar(pos + 2 * width, blue_means, width, color='b', alpha=0.5)

# Set the axis labels and title
ax.set_xlabel('Test Strips')
ax.set_ylabel('Color Intensity(RGB Values)')
ax.set_title('Comparison of RGB Values for Loss of Water Molecules')

# Set the axis ticks and tick labels
ax.set_xticks(pos + width * 1.5-offset)
ax.set_xticklabels(labels, ha='center')
ax.set_yticks(np.arange(0, 256, 25))

# Add the legend
ax.legend((rects1[0], rects2[0], rects3[0]), ('Red', 'Green', 'Blue'))

# Display the plot
plt.show()

# %%
# RGB values for image1 and image2
rgb_image1 = (112.7, 127.44, 156)
rgb_image2 = (127.68, 118.05, 81.35)

# Calculate the average RGB value for each image
average_rgb_image1 = sum(rgb_image1) / 3
average_rgb_image2 = sum(rgb_image2) / 3

# Normalize the average RGB values
normalized_value_image1 = average_rgb_image1 / 255
normalized_value_image2 = average_rgb_image2 / 255

# Print the normalized values
print("Normalized value for image1:", normalized_value_image1)
print("Normalized value for image2:", normalized_value_image2)
# Out:
# Normalized value for image1: 0.5178300653594771
# Normalized value for image2: 0.42755555555555563

# %%
import numpy as np
import matplotlib.pyplot as plt

# Normalized RGB values for image1 and image2
normalized_value_image1 = 0.5178300653594771
normalized_value_image2 = 0.42755555555555563
# Create a list of labels for the images
labels = ['Non-Tested Region of Test Strip', 'Tested Region of Test Strip']

# Create a list of the normalized RGB values
normalized_values = [normalized_value_image1, normalized_value_image2]

# Set the positions and width of the bars
pos = np.arange(len(labels))
width = 0.5

# Create the figure and axis objects
fig, ax = plt.subplots()

# Create the bar plot
rects = ax.bar(pos, normalized_values, width, color='y', alpha=0.5)

# Set the axis labels and title
ax.set_xlabel('Test Strip Tested with water')
ax.set_ylabel('Normalized RGB Value')
ax.set_title('Normalized RGB Values Comparison of Negative Control (in Water)')

# Set the axis ticks and tick labels
ax.set_xticks(pos)
ax.set_xticklabels(labels)

# Add the values on top of each bar
for rect in rects:
    height = rect.get_height()
    ax.annotate(f'{height:.2f}', xy=(rect.get_x() + rect.get_width() / 2, height), xytext=(0, 3), 
                textcoords="offset points", ha='center', va='bottom')

# Display the plot
plt.show()

# %%
# RGB values for image1 and image2
rgb_image3 = (128.57, 126, 119.98)
rgb_image4 = (127.43, 139.3, 168.03)

# Calculate the average RGB value for each image
average_rgb_image1 = sum(rgb_image3) / 3
average_rgb_image2 = sum(rgb_image4) / 3

# Normalize the average RGB values
normalized_value_image1 = average_rgb_image1 / 255
normalized_value_image2 = average_rgb_image2 / 255

# Print the normalized values
print("Normalized value for image1:", normalized_value_image1)
print("Normalized value for image2:", normalized_value_image2)
# Out:
# Normalized value for image1: 0.4896078431372549
# Normalized value for image2: 0.568313725490196

# %%
import numpy as np
import matplotlib.pyplot as plt

# Normalized RGB values for image1 and image2
normalized_value_image1 = 0.4896078431372549
normalized_value_image2 = 0.568313725490196
# Create a list of labels for the images
labels = ['Non-Tested Region of Test Strip', 'Tested Region of Test Strip']

# Create a list of the normalized RGB values
normalized_values = [normalized_value_image1, normalized_value_image2]

# Set the positions and width of the bars
pos = np.arange(len(labels))
width = 0.5

# Create the figure and axis objects
fig, ax = plt.subplots()

# Create the bar plot
rects = ax.bar(pos, normalized_values, width, color='y', alpha=0.5)

# Set the axis labels and title
ax.set_xlabel('Test Strip Tested in Benadryl+Kombucha')
ax.set_ylabel('Normalized RGB Value')
ax.set_title('Normalized RGB Values Comparison of Benadryl in Kombucha')

# Set the axis ticks and tick labels
ax.set_xticks(pos)
ax.set_xticklabels(labels)

# Add the values on top of each bar
for rect in rects:
    height = rect.get_height()
    ax.annotate(f'{height:.2f}', xy=(rect.get_x() + rect.get_width() / 2, height), xytext=(0, 3), 
                textcoords="offset points", ha='center', va='bottom')

# Display the plot
plt.show()

# %%
red_means = [255-207.01, 255-204.42, 255-194.21, 255-169.87]
green_means = [255-201.64, 255-201.83, 255-194.35, 255-165.69]
blue_means = [255-177.72, 255-184.44, 255-178.62, 255-150.87]

normalized_red = [1 - (mean/255) for mean in red_means]
normalized_green = [1 - (mean/255) for mean in green_means]
normalized_blue = [1 - (mean/255) for mean in blue_means]

print("Normalized Red Means:", normalized_red)
print("Normalized Green Means:", normalized_green)
print("Normalized Blue Means:", normalized_blue)
# Out:
# Normalized Red Means: [0.8118039215686275, 0.8016470588235294, 0.7616078431372549, 0.666156862745098]
# Normalized Green Means: [0.7907450980392157, 0.7914901960784314, 0.7621568627450981, 0.6497647058823529]
# Normalized Blue Means: [0.6969411764705882, 0.7232941176470589, 0.7004705882352942, 0.5916470588235294]

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the data
labels = ['Simply Spiked(5%)', 'Smirnoff(4.5%)', 'Cayman Jack(5.8%)', 'Cayman Jack(5.8%)+Black Dye']
normalized_red_means = [0.8118039215686275, 0.8016470588235294, 0.7616078431372549, 0.666156862745098]
normalized_green_means = [0.7907450980392157, 0.7914901960784314, 0.7621568627450981, 0.6497647058823529]
normalized_blue_means = [0.6969411764705882, 0.7232941176470589, 0.7004705882352942, 0.5916470588235294]

# Set the positions and width of the bars
pos = np.arange(len(labels))
width = 0.25
offset = 0.12

# Create the figure and axis objects
fig, ax = plt.subplots(figsize=(10, 6))

# Create the bar plots
rects1 = ax.bar(pos, normalized_red_means, width, color='r', alpha=0.5)
rects2 = ax.bar(pos + width, normalized_green_means, width, color='g', alpha=0.5)
rects3 = ax.bar(pos + 2 * width, normalized_blue_means, width, color='b', alpha=0.5)

# Set the axis labels and title
ax.set_xlabel('Test Strip Samples of Hard Seltzers with \u22482% Diphenhydramine HCl (Benadryl)')
ax.set_ylabel('Normalized RGB Values')
ax.set_title('Normalized RGB Values Analysis of Test Strip Samples')

# Set the axis ticks and tick labels
ax.set_xticks(pos + width * 1.5 - offset)
ax.set_xticklabels(labels, ha='center')
ax.set_yticks(np.arange(0, 1.1, 0.1))

# Add the legend
ax.legend((rects1[0], rects2[0], rects3[0]), ('Red', 'Green', 'Blue'))

# Display the plot
plt.show()

# %%
import scipy.stats as stats

# Define the data arrays
baseline_red = [164.59]
baseline_green = [174.12]
baseline_blue = [188.31]

simply_spiked_red = [207.01]
simply_spiked_green = [201.64]
simply_spiked_blue = [177.72]

smirnoff_red = [204.42]
smirnoff_green = [201.83]
smirnoff_blue = [184.44]

cayman_jack_red = [194.21]
cayman_jack_green = [194.35]
cayman_jack_blue = [178.62]

cayman_jack_black_red = [169.87]
cayman_jack_black_green = [165.69]
cayman_jack_black_blue = [150.87]

# Perform one-way ANOVA
red_results = stats.f_oneway(baseline_red, simply_spiked_red, smirnoff_red, cayman_jack_red, cayman_jack_black_red)
green_results = stats.f_oneway(baseline_green, simply_spiked_green, smirnoff_green, cayman_jack_green, cayman_jack_black_green)
blue_results = stats.f_oneway(baseline_blue, simply_spiked_blue, smirnoff_blue, cayman_jack_blue, cayman_jack_black_blue)

# Print the ANOVA results
print("Red ANOVA results:", red_results)
print("Green ANOVA results:", green_results)
print("Blue ANOVA results:", blue_results)
# Out:
# Red ANOVA results: F_onewayResult(statistic=nan, pvalue=nan)
# Green ANOVA results: F_onewayResult(statistic=nan, pvalue=nan)
# Blue ANOVA results: F_onewayResult(statistic=nan, pvalue=nan)
# C:\Users\user\anaconda3\lib\site-packages\scipy\stats\_stats_py.py:3877: DegenerateDataWarning: all input arrays have length 1.  f_oneway requires that at least one input has length greater than 1.
#   warnings.warn(stats.DegenerateDataWarning(msg))

# %%
from scipy.stats import kruskal, mannwhitneyu

# Perform Kruskal-Wallis test
red_kw_stat, red_kw_pvalue = kruskal(*red_values)
green_kw_stat, green_kw_pvalue = kruskal(*green_values)
blue_kw_stat, blue_kw_pvalue = kruskal(*blue_values)

# Perform pairwise Mann-Whitney U tests
red_mw_pvalues = [207.01,201.64,194.21]
green_mw_pvalues = [204.42,201.83,194.35]
blue_mw_pvalues = [194.21,194.35,178.62]

for i in range(len(red_values)):
    for j in range(i + 1, len(red_values)):
        mw_stat, mw_pvalue = mannwhitneyu(red_values[i], red_values[j])
        red_mw_pvalues.append((i, j, mw_pvalue))

for i in range(len(green_values)):
    for j in range(i + 1, len(green_values)):
        mw_stat, mw_pvalue = mannwhitneyu(green_values[i], green_values[j])
        green_mw_pvalues.append((i, j, mw_pvalue))

for i in range(len(blue_values)):
    for j in range(i + 1, len(blue_values)):
        mw_stat, mw_pvalue = mannwhitneyu(blue_values[i], blue_values[j])
        blue_mw_pvalues.append((i, j, mw_pvalue))

# Print the results
print("Red Kruskal-Wallis Test:")
print("Kruskal-Wallis statistic:", red_kw_stat)
print("p-value:", red_kw_pvalue)
print()

print("Green Kruskal-Wallis Test:")
print("Kruskal-Wallis statistic:", green_kw_stat)
print("p-value:", green_kw_pvalue)
print()

print("Blue Kruskal-Wallis Test:")
print("Kruskal-Wallis statistic:", blue_kw_stat)
print("p-value:", blue_kw_pvalue)
print()

print("Pairwise Mann-Whitney U tests (Red Component):")
for i, j, p in red_mw_pvalues:
    print(f"Comparison between test strip {i+1} and test strip {j+1}: p-value = {p}")
print()

print("Pairwise Mann-Whitney U tests (Green Component):")
for i, j, p in green_mw_pvalues:
    print(f"Comparison between test strip {i+1} and test strip {j+1}: p-value = {p}")
print()

print("Pairwise Mann-Whitney U tests (Blue Component):")
for i, j, p in blue_mw_pvalues:
    print(f"Comparison between test strip {i+1} and test strip {j+1}: p-value = {p}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17888\4106226755.py in <module>
#       2
#       3 # Perform Kruskal-Wallis test
# ----> 4 red_kw_stat, red_kw_pvalue = kruskal(*red_values)
#       5 green_kw_stat, green_kw_pvalue = kruskal(*green_values)
#       6 blue_kw_stat, blue_kw_pvalue = kruskal(*blue_values)
#
# NameError: name 'red_values' is not defined

# %%
from scipy.stats import kruskal, mannwhitneyu

# Define the RGB values for each test strip
red_values = [207.01,201.64,194.21
    # Define the red component values for each test strip
]

green_values = [204.42,201.83,194.35
    # Define the green component values for each test strip
]

blue_values = [194.21,194.35,178.62
    # Define the blue component values for each test strip
]

# Perform Kruskal-Wallis test
red_kw_stat, red_kw_pvalue = kruskal(*red_values)
green_kw_stat, green_kw_pvalue = kruskal(*green_values)
blue_kw_stat, blue_kw_pvalue = kruskal(*blue_values)

# Perform pairwise Mann-Whitney U tests
red_mw_pvalues = []
green_mw_pvalues = []
blue_mw_pvalues = []

for i in range(len(red_values)):
    for j in range(i + 1, len(red_values)):
        mw_stat, mw_pvalue = mannwhitneyu(red_values[i], red_values[j])
        red_mw_pvalues.append((i, j, mw_pvalue))

for i in range(len(green_values)):
    for j in range(i + 1, len(green_values)):
        mw_stat, mw_pvalue = mannwhitneyu(green_values[i], green_values[j])
        green_mw_pvalues.append((i, j, mw_pvalue))

for i in range(len(blue_values)):
    for j in range(i + 1, len(blue_values)):
        mw_stat, mw_pvalue = mannwhitneyu(blue_values[i], blue_values[j])
        blue_mw_pvalues.append((i, j, mw_pvalue))

# Print the results
print("Red Kruskal-Wallis Test:")
print("Kruskal-Wallis statistic:", red_kw_stat)
print("p-value:", red_kw_pvalue)
print()

print("Green Kruskal-Wallis Test:")
print("Kruskal-Wallis statistic:", green_kw_stat)
print("p-value:", green_kw_pvalue)
print()

print("Blue Kruskal-Wallis Test:")
print("Kruskal-Wallis statistic:", blue_kw_stat)
print("p-value:", blue_kw_pvalue)
print()

print("Pairwise Mann-Whitney U tests (Red Component):")
for i, j, p in red_mw_pvalues:
    print(f"Comparison between test strip {i+1} and test strip {j+1}: p-value = {p}")
print()

print("Pairwise Mann-Whitney U tests (Green Component):")
for i, j, p in green_mw_pvalues:
    print(f"Comparison between test strip {i+1} and test strip {j+1}: p-value = {p}")
print()

print("Pairwise Mann-Whitney U tests (Blue Component):")
for i, j, p in blue_mw_pvalues:
    print(f"Comparison between test strip {i+1} and test strip {j+1}: p-value = {p}")
# Out:
# Red Kruskal-Wallis Test:
# Kruskal-Wallis statistic: 2.0
# p-value: 0.36787944117144245
#
# Green Kruskal-Wallis Test:
# Kruskal-Wallis statistic: 2.0
# p-value: 0.36787944117144245
#
# Blue Kruskal-Wallis Test:
# Kruskal-Wallis statistic: 2.0
# p-value: 0.36787944117144245
#
# Pairwise Mann-Whitney U tests (Red Component):
# Comparison between test strip 1 and test strip 2: p-value = 1.0
# Comparison between test strip 1 and test strip 3: p-value = 1.0
# Comparison between test strip 2 and test strip 3: p-value = 1.0
#
# Pairwise Mann-Whitney U tests (Green Component):
# Comparison between test strip 1 and test strip 2: p-value = 1.0
# Comparison between test strip 1 and test strip 3: p-value = 1.0
# Comparison between test strip 2 and test strip 3: p-value = 1.0
#
# Pairwise Mann-Whitney U tests (Blue Component):
# Comparison between test strip 1 and test strip 2: p-value = 1.0
# Comparison between test strip 1 and test strip 3: p-value = 1.0
# ...
